# %% [markdown]
# ## Summary
#
# The notebook employs the LyricsGenius API, a third-party Python package, to scrape Genius.com for lyrics data. It begins by loading .csv files containing lists of artists sorted into specific genres. A custom function is then used to scrape data about these artists from Genius.com and save it to a separate .csv file. Due to occasional failures of the LyricsGenius API, the notebook includes a specialized cell designed to resume scraping from the last point reached in the list, ensuring continuity in data collection despite the API's intermittent challenges.

# %%
#Get access token for Genuis.com

import json 
f = open("path/to/credentials")
data = json.load(f)
token = data["access_token"]
#print(token)

# %%
# look at artists csv
import pandas as pd

artist_df = pd.read_csv("data/artist-main-genre.csv")
display(artist_df)
# Out:
#                  artist    genre
# 0             Sean Paul      pop
# 1           Chris Brown      pop
# 2            Nickelback     rock
# 3                 Ne-Yo      rap
# 4              The Fray      pop
# ..                  ...      ...
# 568  Tyler, The Creator      rap
# 569            Lil Tjay      rap
# 570            Anuel AA      rap
# 571          Chase Rice  country
# 572     Scotty McCreery  country
#
# [573 rows x 2 columns]

# %%
artist_df.groupby("genre").count()
country_list = artist_df[artist_df["genre"]=="country"]["artist"].tolist()
rap_list = artist_df[artist_df["genre"]=="rap"]["artist"].tolist()
rock_list = artist_df[artist_df["genre"]=="rock"]["artist"].tolist()
pop_list = artist_df[artist_df["genre"]=="pop"]["artist"].tolist()

print(rap_list)
# Out:
# ['Ne-Yo', 'T.I.', 'Yung Joc', 'Nelly Furtado', 'Gnarls Barkley', 'Chamillionaire', 'Nelly', 'Dem Franchize Boyz', 'Eminem', 'T-Pain', 'Ludacris', 'Jamie Foxx', 'Cascada', 'D4L', 'Kanye West', 'E-40', 'Juelz Santana', 'Busta Rhymes', 'Lil Jon', 'Three 6 Mafia', 'Bubba Sparxxx', 'Jibbs', 'Lil Wayne', 'Field Mob', 'Daddy Yankee', 'Wyclef Jean', 'Bow Wow', 'Young Dro', 'Paul Wall', 'Chingy', 'Krayzie Bone', 'Slim Thug', 'Gorillaz', 'Snoop Dogg', 'Mims', 'Shop Boyz', "Soulja Boy Tell'em", 'Jim Jones', 'JAY-Z', 'Diddy', 'Hurricane Chris', 'Fabolous', '50 Cent', 'Fat Joe', 'Plies', 'Pretty Ricky', 'Baby Boy Da Prince', 'Bone Thugs-N-Harmony', 'Rich Boy', 'DJ Khaled', 'Eve', 'Yung Berg', 'Kardinal Offishall', "Colby O'Donis", 'Webbie', 'Rick Ross', 'Baby Bash', 'Lupe Fiasco', 'David Banner', 'The Game', 'Drake', 'Kid Cudi', 'Jeremih', 'Young Money', 'Asher Roth', 'New Boyz', 'Dorrough', 'B.o.B', 'Gucci Mane', 'Cali Swag District', 'CeeLo Green', 'Wiz Khalifa', 'Bad Meets Evil', 'Dr. Dre', 'Waka Flocka Flame', 'Big Sean', 'Edward Maya', 'Tyga', '2 Chainz', 'J. Cole', 'Kirko Bangz', 'Ca$h Out', 'Future', 'Wale', 'Kendrick Lamar', 'Daft Punk', 'A$AP Rocky', 'Sage The Gemini', 'Juicy J', 'Trinidad James', 'MAGIC!', 'YG', 'Kid Ink', 'ScHoolboy Q', 'Bobby Shmurda', 'Young Thug', 'Rae Sremmurd', 'Ty Dolla $ign', 'Rich Homie Quan', 'Fetty Wap', 'Silento', 'T-Wayne', 'R. City', 'Meek Mill', 'O.T. Genasis', 'M0', 'DeJ Loaf', 'Jidenna', 'I LOVE MAKONNEN', 'Desiigner', 'Bryson Tiller', 'Kevin Gates', 'Tory Lanez', 'G-Eazy', 'Kent Jones', 'Travis Scott', 'Post Malone', 'Prince', 'Lil Uzi Vert', 'Lil Yachty', 'Yo Gotti', 'Kyla', 'MadeinTYO', 'Migos', 'Kodak Black', '21 Savage', 'Cardi B', 'Childish Gambino', 'Quavo', 'French Montana', 'XXXTENTACION', 'KYLE', 'Logic', 'SZA', 'Amine', 'Ayo & Teo', 'Playboi Carti', 'Machine Gun Kelly', 'A Boogie Wit da Hoodie', 'Jon Bellion', 'Swae Lee', 'Juice WRLD', 'Lil Pump', 'NF', 'Lil Baby', 'YoungBoy Never Broke Again', 'Rich The Kid', 'Bad Bunny', 'BlocBoy JB', 'Offset', 'Famous Dex', 'Metro Boomin', 'Lil Dicky', 'Lil Skies', 'A$AP Ferg', 'Lil Nas X', 'DaBaby', 'Lizzo', 'Lil Tecca', 'YNW Melly', 'Gunna', 'Blueface', 'City Girls', 'Sheck Wes', 'Calboy', 'Megan Thee Stallion', 'Mustard', 'NLE Choppa', 'Flipp Dinero', 'Polo G', 'Pinkfong', 'Saweetie', 'YK Osiris', 'Tyler, The Creator', 'Lil Tjay', 'Anuel AA']

# %%
test_list = rap_list[:3]
print(test_list)
# Out:
# ['Ne-Yo', 'T.I.', 'Yung Joc']

# %%
import csv
import requests
import lyricsgenius as lg

# Define the fields for the CSV where the lyrics will be stored
fields = ["title", "artist", "lyrics"]

# Setup the Genius API with a token and specific settings to filter and format the lyrics
genius = lg.Genius(token, skip_non_songs=True,
                   excluded_terms=["(Remix)", "(Live)"],
                   remove_section_headers=True, verbose=False, retries=5)

# Define a function to retrieve lyrics for a list of artists
def get_lyrics(artists: list, max_songs: int, output_path: str, write_headers: bool):
    c = 0  # Initialize a counter for the songs
    
    # Open the CSV file for appending data
    csvfile = open(output_path, "a")
    # Create a CSV DictWriter object to handle the writing of data
    writer = csv.DictWriter(csvfile, fieldnames=fields, restval='')
    
    # If specified, write the header row in the CSV file
    if write_headers:
        writer.writeheader()
    
    # Iterate over the list of artists to retrieve their songs
    for name in artists:
        try:
            # Search for the artist on Genius and get their songs
            songs = (genius.search_artist(name, max_songs=max_songs)).songs
            for song in songs:
                try:
                    c += 1  # Increment the song counter
                    # Create a dictionary for the current song with the desired information
                    song_dict = {
                        "title": song.title,
                        "artist": song.artist,
                        # Clean up the lyrics by replacing new lines with colons and splitting by the word "Lyrics:"
                        "lyrics": song.lyrics.replace("\n", ":").split("Lyrics:")[1]
                    }
                    # Write the song's information to the CSV file
                    writer.writerow(song_dict)
                except Exception as e:
                    # If an exception occurs during the song data processing, print the exception
                    print(f"Exception at {name}: {c}, {str(e)}")
            # Print a success message for the artist once all their songs are processed
            print(f"-----------------{song.artist} SUCCESSFULLY ADDED-------------------- \n"
                  f"  SONG COUNT: {c}")
        except requests.exceptions.HTTPError as error:
            # Handle HTTP errors during the artist search
            print("HTTP Error")
            print(error.args[0])
    # Close the CSV file after writing is complete
    csvfile.close()

# %%
#get rap artist data
# get_lyrics(rap_list, 200, "data/rap_lyrics.csv")

# %%
#find where script failed and function at that point
rap_df = pd.read_csv("data/rap_lyrics 2.csv")
print(rap_df.iloc[[len(rap_df)-1]].artist)

modified_rap_list = rap_list[rap_list.index("Migos")+1:]
display(modified_rap_list)
# Out:
# 14480    Migos
# Name: artist, dtype: object
# ['Kodak Black',
#  '21 Savage',
#  'Cardi B',
#  'Childish Gambino',
#  'Quavo',
#  'French Montana',
#  'XXXTENTACION',
#  'KYLE',
#  'Logic',
#  'SZA',
#  'Amine',
#  'Ayo & Teo',
#  'Playboi Carti',
#  'Machine Gun Kelly',
#  'A Boogie Wit da Hoodie',
#  'Jon Bellion',
#  'Swae Lee',
#  'Juice WRLD',
#  'Lil Pump',
#  'NF',
#  'Lil Baby',
#  'YoungBoy Never Broke Again',
#  'Rich The Kid',
#  'Bad Bunny',
#  'BlocBoy JB',
#  'Offset',
#  'Famous Dex',
#  'Metro Boomin',
#  'Lil Dicky',
#  'Lil Skies',
#  'A$AP Ferg',
#  'Lil Nas X',
#  'DaBaby',
#  'Lizzo',
#  'Lil Tecca',
#  'YNW Melly',
#  'Gunna',
#  'Blueface',
#  'City Girls',
#  'Sheck Wes',
#  'Calboy',
#  'Megan Thee Stallion',
#  'Mustard',
#  'NLE Choppa',
#  'Flipp Dinero',
#  'Polo G',
#  'Pinkfong',
#  'Saweetie',
#  'YK Osiris',
#  'Tyler, The Creator',
#  'Lil Tjay',
#  'Anuel AA']

# %%
get_lyrics(modified_rap_list,200, "data/rap_lyrics 2.csv", write_headers=False)
# Out:
# Exception at Kodak Black: 43
# Exception at Kodak Black: 88
# Exception at Kodak Black: 199
# -----------------Kodak Black SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 200
# Exception at 21 Savage: 313
# Exception at 21 Savage: 331
# Exception at 21 Savage: 333
# Exception at 21 Savage: 339
# Exception at 21 Savage: 340
# Exception at 21 Savage: 341
# Exception at 21 Savage: 344
# Exception at 21 Savage: 346
# Exception at 21 Savage: 347
# Exception at 21 Savage: 350
# Exception at 21 Savage: 351
# Exception at 21 Savage: 353
# Exception at 21 Savage: 357
# Exception at 21 Savage: 358
# Exception at 21 Savage: 361
# Exception at 21 Savage: 362
# Exception at 21 Savage: 363
# Exception at 21 Savage: 365
# Exception at 21 Savage: 367
# Exception at 21 Savage: 368
# -----------------21 Savage SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 369
# Exception at Cardi B: 401
# Exception at Cardi B: 402
# Exception at Cardi B: 403
# Exception at Cardi B: 406
# Exception at Cardi B: 416
# Exception at Cardi B: 418
# Exception at Cardi B: 421
# Exception at Cardi B: 432
# Exception at Cardi B: 434
# Exception at Cardi B: 436
# Exception at Cardi B: 437
# Exception at Cardi B: 438
# Exception at Cardi B: 441
# Exception at Cardi B: 442
# Exception at Cardi B: 443
# Exception at Cardi B: 444
# Exception at Cardi B: 445
# Exception at Cardi B: 446
# Exception at Cardi B: 447
# Exception at Cardi B: 448
# Exception at Cardi B: 451
# Exception at Cardi B: 455
# Exception at Cardi B: 456
# -----------------Cardi B SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 456
# Exception at Childish Gambino: 480
# Exception at Childish Gambino: 514
# Exception at Childish Gambino: 515
# Exception at Childish Gambino: 521
# Exception at Childish Gambino: 530
# Exception at Childish Gambino: 532
# Exception at Childish Gambino: 540
# Exception at Childish Gambino: 542
# Exception at Childish Gambino: 547
# Exception at Childish Gambino: 550
# Exception at Childish Gambino: 576
# Exception at Childish Gambino: 581
# Exception at Childish Gambino: 586
# Exception at Childish Gambino: 589
# Exception at Childish Gambino: 591
# Exception at Childish Gambino: 594
# Exception at Childish Gambino: 597
# Exception at Childish Gambino: 598
# Exception at Childish Gambino: 601
# Exception at Childish Gambino: 603
# Exception at Childish Gambino: 613
# Exception at Childish Gambino: 617
# Exception at Childish Gambino: 618
# Exception at Childish Gambino: 619
# Exception at Childish Gambino: 626
# Exception at Childish Gambino: 641
# Exception at Childish Gambino: 648
# -----------------Childish Gambino SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 656
# Exception at Quavo: 700
# Exception at Quavo: 707
# Exception at Quavo: 711
# Exception at Quavo: 714
# Exception at Quavo: 718
# Exception at Quavo: 719
# Exception at Quavo: 733
# Exception at Quavo: 735
# Exception at Quavo: 741
# Exception at Quavo: 746
# Exception at Quavo: 750
# Exception at Quavo: 751
# Exception at Quavo: 760
# Exception at Quavo: 761
# -----------------Quavo SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 761
# Exception at French Montana: 812
# Exception at French Montana: 822
# Exception at French Montana: 850
# Exception at French Montana: 878
# Exception at French Montana: 880
# Exception at French Montana: 883
# Exception at French Montana: 891
# Exception at French Montana: 894
# Exception at French Montana: 928
# Exception at French Montana: 931
# Exception at French Montana: 939
# Exception at French Montana: 940
# Exception at French Montana: 952
# Exception at French Montana: 956
# -----------------French Montana SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 961
# Exception at XXXTENTACION: 1024
# Exception at XXXTENTACION: 1051
# Exception at XXXTENTACION: 1055
# Exception at XXXTENTACION: 1095
# Exception at XXXTENTACION: 1109
# Exception at XXXTENTACION: 1118
# Exception at XXXTENTACION: 1125
# Exception at XXXTENTACION: 1146
# Exception at XXXTENTACION: 1149
# Exception at XXXTENTACION: 1150
# Exception at XXXTENTACION: 1151
# Exception at XXXTENTACION: 1153
# Exception at XXXTENTACION: 1154
# Exception at XXXTENTACION: 1159
# Exception at XXXTENTACION: 1160
# -----------------XXXTENTACION SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1161
# Exception at KYLE: 1243
# Exception at KYLE: 1253
# Exception at KYLE: 1261
# Exception at KYLE: 1272
# Exception at KYLE: 1275
# Exception at KYLE: 1278
# Exception at KYLE: 1279
# Exception at KYLE: 1284
# Exception at KYLE: 1287
# Exception at KYLE: 1294
# Exception at KYLE: 1295
# Exception at KYLE: 1298
# Exception at KYLE: 1299
# Exception at KYLE: 1300
# Exception at KYLE: 1303
# Exception at KYLE: 1306
# Exception at KYLE: 1317
# Exception at KYLE: 1319
# Exception at KYLE: 1320
# Exception at KYLE: 1321
# Exception at KYLE: 1322
# Exception at KYLE: 1323
# -----------------KYLE SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1323
# Exception at Logic: 1450
# -----------------Logic SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1523
# Exception at SZA: 1583
# Exception at SZA: 1596
# Exception at SZA: 1607
# Exception at SZA: 1610
# Exception at SZA: 1617
# Exception at SZA: 1621
# Exception at SZA: 1622
# Exception at SZA: 1623
# Exception at SZA: 1624
# Exception at SZA: 1628
# Exception at SZA: 1629
# Exception at SZA: 1632
# Exception at SZA: 1650
# Exception at SZA: 1651
# Exception at SZA: 1661
# Exception at SZA: 1666
# Exception at SZA: 1669
# Exception at SZA: 1670
# Exception at SZA: 1674
# Exception at SZA: 1675
# Exception at SZA: 1676
# Exception at SZA: 1677
# Exception at SZA: 1679
# Exception at SZA: 1680
# Exception at SZA: 1681
# Exception at SZA: 1683
# Exception at SZA: 1685
# Exception at SZA: 1687
# Exception at SZA: 1689
# Exception at SZA: 1694
# Exception at SZA: 1695
# Exception at SZA: 1699
# Exception at SZA: 1704
# Exception at SZA: 1705
# Exception at SZA: 1706
# Exception at SZA: 1708
# Exception at SZA: 1709
# Exception at SZA: 1710
# Exception at SZA: 1717
# Exception at SZA: 1718
# Exception at SZA: 1719
# -----------------SZA SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1720
# Exception at Amine: 1820
# Exception at Amine: 1827
# Exception at Amine: 1830
# Exception at Amine: 1832
# Exception at Amine: 1833
# Exception at Amine: 1834
# Exception at Amine: 1835
# -----------------Aminé SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1835
# Exception at Ayo & Teo: 1854
# Exception at Ayo & Teo: 1857
# Exception at Ayo & Teo: 1859
# Exception at Ayo & Teo: 1861
# Exception at Ayo & Teo: 1863
# Exception at Ayo & Teo: 1865
# Exception at Ayo & Teo: 1868
# Exception at Ayo & Teo: 1869
# Exception at Ayo & Teo: 1870
# -----------------Ayo & Teo SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1870
# Exception at Playboi Carti: 1975
# Exception at Playboi Carti: 1987
# Exception at Playboi Carti: 1991
# Exception at Playboi Carti: 1997
# Exception at Playboi Carti: 2002
# Exception at Playboi Carti: 2005
# Exception at Playboi Carti: 2015
# Exception at Playboi Carti: 2035
# Exception at Playboi Carti: 2039
# Exception at Playboi Carti: 2040
# Exception at Playboi Carti: 2043
# Exception at Playboi Carti: 2046
# Exception at Playboi Carti: 2057
# Exception at Playboi Carti: 2062
# Exception at Playboi Carti: 2068
# -----------------Playboi Carti SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 2070
# Exception at Machine Gun Kelly: 2081
# Exception at Machine Gun Kelly: 2202
# Exception at Machine Gun Kelly: 2225
# Exception at Machine Gun Kelly: 2240
# Exception at Machine Gun Kelly: 2250
# Exception at Machine Gun Kelly: 2252
# Exception at Machine Gun Kelly: 2254
# Exception at Machine Gun Kelly: 2263
# -----------------Machine Gun Kelly SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 2270
# Exception at A Boogie Wit da Hoodie: 2407
# Exception at A Boogie Wit da Hoodie: 2410
# Exception at A Boogie Wit da Hoodie: 2430
# Exception at A Boogie Wit da Hoodie: 2432
# Exception at A Boogie Wit da Hoodie: 2434
# Exception at A Boogie Wit da Hoodie: 2436
# Exception at A Boogie Wit da Hoodie: 2438
# Exception at A Boogie Wit da Hoodie: 2439
# Exception at A Boogie Wit da Hoodie: 2443
# Exception at A Boogie Wit da Hoodie: 2447
# Exception at Sean Paul: 133
# Exception at Sean Paul: 136
# Exception at Sean Paul: 143
# Exception at Sean Paul: 146
# Exception at Sean Paul: 147
# Exception at Sean Paul: 151
# Exception at Sean Paul: 155
# Exception at Sean Paul: 156
# Exception at Sean Paul: 157
# Exception at Sean Paul: 158
# Exception at Sean Paul: 162
# Exception at Sean Paul: 163
# Exception at Sean Paul: 165
# Exception at Sean Paul: 166
# Exception at Sean Paul: 167
# Exception at Sean Paul: 168
# Exception at Sean Paul: 169
# Exception at Sean Paul: 171
# Exception at Sean Paul: 174
# Exception at Sean Paul: 176
# Exception at Sean Paul: 181
# Exception at Sean Paul: 184
# Exception at Sean Paul: 185
# Exception at Sean Paul: 186
# Exception at Sean Paul: 197
# Exception at Sean Paul: 198
# -----------------Sean Paul SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 200
# -----------------Chris Brown SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 400
# Exception at The Fray: 407
# Exception at The Fray: 430
# Exception at The Fray: 434
# Exception at The Fray: 440
# Exception at The Fray: 449
# Exception at The Fray: 455
# Exception at The Fray: 456
# Exception at The Fray: 459
# Exception at The Fray: 462
# Exception at The Fray: 464
# Exception at The Fray: 465
# Exception at The Fray: 466
# Exception at The Fray: 468
# Exception at The Fray: 471
# Exception at The Fray: 472
# Exception at The Fray: 473
# Exception at The Fray: 475
# Exception at The Fray: 476
# Exception at The Fray: 479
# Exception at The Fray: 480
# Exception at The Fray: 481
# Exception at The Fray: 482
# Exception at The Fray: 483
# -----------------The Fray SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 483
# Exception at Rihanna: 530
# Exception at Rihanna: 655
# Exception at Rihanna: 662
# Exception at Rihanna: 664
# -----------------Rihanna SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 683
# Exception at The Pussycat Dolls: 727
# Exception at The Pussycat Dolls: 729
# Exception at The Pussycat Dolls: 736
# Exception at The Pussycat Dolls: 738
# Exception at The Pussycat Dolls: 739
# Exception at The Pussycat Dolls: 747
# Exception at The Pussycat Dolls: 749
# Exception at The Pussycat Dolls: 751
# Exception at The Pussycat Dolls: 754
# Exception at The Pussycat Dolls: 755
# -----------------The Pussycat Dolls SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 755
# Exception at Justin Timberlake: 810
# Exception at Justin Timberlake: 814
# Exception at Justin Timberlake: 832
# Exception at Justin Timberlake: 839
# Exception at Justin Timberlake: 842
# Exception at Justin Timberlake: 843
# Exception at Justin Timberlake: 847
# Exception at Justin Timberlake: 850
# Exception at Justin Timberlake: 852
# Exception at Justin Timberlake: 855
# Exception at Justin Timberlake: 856
# Exception at Justin Timberlake: 858
# Exception at Justin Timberlake: 860
# Exception at Justin Timberlake: 862
# Exception at Justin Timberlake: 863
# Exception at Justin Timberlake: 864
# Exception at Justin Timberlake: 866
# Exception at Justin Timberlake: 869
# Exception at Justin Timberlake: 870
# Exception at Justin Timberlake: 871
# Exception at Justin Timberlake: 875
# Exception at Justin Timberlake: 876
# Exception at Justin Timberlake: 877
# Exception at Justin Timberlake: 878
# Exception at Justin Timberlake: 881
# Exception at Justin Timberlake: 883
# -----------------Justin Timberlake SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 883
# Exception at Beyonce: 886
# Exception at Beyonce: 909
# Exception at Beyonce: 921
# Exception at Beyonce: 986
# Exception at Beyonce: 1013
# Exception at Beyonce: 1021
# Exception at Beyonce: 1041
# Exception at Beyonce: 1045
# Exception at Beyonce: 1053
# Exception at Beyonce: 1054
# Exception at Beyonce: 1055
# Exception at Beyonce: 1071
# Exception at Beyonce: 1073
# Exception at Beyonce: 1078
# -----------------Beyoncé SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1083
# Exception at Mary J. Blige: 1146
# Exception at Mary J. Blige: 1154
# Exception at Mary J. Blige: 1159
# Exception at Mary J. Blige: 1178
# Exception at Mary J. Blige: 1195
# Exception at Mary J. Blige: 1199
# Exception at Mary J. Blige: 1207
# Exception at Mary J. Blige: 1216
# Exception at Mary J. Blige: 1225
# Exception at Mary J. Blige: 1227
# Exception at Mary J. Blige: 1228
# Exception at Mary J. Blige: 1231
# Exception at Mary J. Blige: 1273
# -----------------Mary J. Blige SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1283
# Exception at James Blunt: 1337
# Exception at James Blunt: 1342
# Exception at James Blunt: 1353
# Exception at James Blunt: 1354
# Exception at James Blunt: 1357
# Exception at James Blunt: 1358
# Exception at James Blunt: 1360
# Exception at James Blunt: 1364
# Exception at James Blunt: 1366
# Exception at James Blunt: 1369
# Exception at James Blunt: 1370
# Exception at James Blunt: 1373
# Exception at James Blunt: 1375
# Exception at James Blunt: 1376
# Exception at James Blunt: 1377
# Exception at James Blunt: 1378
# Exception at James Blunt: 1379
# Exception at James Blunt: 1381
# Exception at James Blunt: 1382
# Exception at James Blunt: 1383
# Exception at James Blunt: 1384
# Exception at James Blunt: 1385
# Exception at James Blunt: 1386
# Exception at James Blunt: 1387
# Exception at James Blunt: 1388
# Exception at James Blunt: 1389
# Exception at James Blunt: 1390
# Exception at James Blunt: 1391
# Exception at James Blunt: 1392
# Exception at James Blunt: 1393
# Exception at James Blunt: 1394
# Exception at James Blunt: 1395
# -----------------James Blunt SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1395
# Exception at Kelly Clarkson: 1434
# Exception at Kelly Clarkson: 1455
# Exception at Kelly Clarkson: 1484
# Exception at Kelly Clarkson: 1531
# Exception at Kelly Clarkson: 1580
# Exception at Kelly Clarkson: 1592
# -----------------Kelly Clarkson SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1595
# Exception at Natasha Bedingfield: 1641
# Exception at Natasha Bedingfield: 1658
# Exception at Natasha Bedingfield: 1676
# Exception at Natasha Bedingfield: 1706
# Exception at Natasha Bedingfield: 1710
# Exception at Natasha Bedingfield: 1712
# Exception at Natasha Bedingfield: 1716
# -----------------Natasha Bedingfield SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1716
# Exception at Fergie: 1756
# Exception at Fergie: 1767
# Exception at Fergie: 1783
# -----------------Fergie SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1789
# Exception at Cassie: 1814
# Exception at Cassie: 1834
# Exception at Cassie: 1857
# Exception at Cassie: 1873
# Exception at Cassie: 1876
# Exception at Cassie: 1880
# Exception at Cassie: 1883
# Exception at Cassie: 1884
# Exception at Cassie: 1908
# Exception at Cassie: 1910
# Exception at Cassie: 1911
# -----------------Cassie SUCCESSFULLY ADDED--------------------
#   SONG COUNT: 1911

# %%
#get country artist data
get_lyrics(country_list, 200, "data/country_lyrics.csv", write_headers=True)

# %%
#get rock artist data
get_lyrics(rock_list, 200, "data/rock_lyrics.csv", write_headers=True)
